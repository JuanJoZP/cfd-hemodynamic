# %%
from mpi4py import MPI
from dolfinx import mesh, io, fem
from petsc4py.PETSc import ScalarType
import numpy as np
import ufl

# %%
# simulation parameters
MESH_CORNERS=((0.0, 0.0), (1.0, 1.0))
N = (16, 16)
TIME_STEP = 0.01
FINAL_TIME = 0.05
PRESSURE_CORRECTION_TOLERANCE = 1e-3
DEBUG = True

# %%
domain = mesh.create_rectangle(comm=MPI.COMM_WORLD, points=MESH_CORNERS, n=N) 

#with io.XDMFFile(MPI.COMM_WORLD, "mesh.xdmf", "w") as xdmf:
#    xdmf.write_mesh(domain)

# physical parameters
rho = fem.Constant(domain, ScalarType(1.0)) # fluid density
mu = fem.Constant(domain, ScalarType(0.005)) # fluid viscosity

from math import pi, tan, exp
smallest_angle = pi/4 # get smaller angle in mesh with help of external software
k_mu = ScalarType(18*mu/tan(smallest_angle)) # SI penalty, asumed constant viscosity and polynomials of deegre 2
# see https://doi.org/10.1016/j.cam.2006.08.029 eq. (48)

# %%
velocity_function_space = fem.functionspace(domain, ("Discontinuous Lagrange", 2, (2,))) # Lagrange deegre 2, vector 2x1
pressure_function_space = fem.functionspace(domain, ("Discontinuous Lagrange", 1)) # Lagrange deegre 2, scalar

u = ufl.TrialFunction(velocity_function_space)
p = ufl.TrialFunction(pressure_function_space)

v = ufl.TestFunction(velocity_function_space)
q = ufl.TestFunction(pressure_function_space)

u_n = fem.Function(velocity_function_space) # one time step before (known)
u_n_1 = fem.Function(velocity_function_space) # two time step before (known)
# initialized as zero, so initial condition is u(x, 0) = 0

x = ufl.SpatialCoordinate(domain)
decay_factor =  exp(-2 * np.pi ** 2 * mu * TIME_STEP)
u_n_1.interpolate(lambda x: np.vstack((-np.sin(np.pi * x[1]) * np.cos(np.pi * x[0]),
                                          np.sin(np.pi * x[0]) * np.cos(np.pi * x[1]))))
u_n.interpolate(lambda x: np.vstack((-np.sin(np.pi * x[1]) * np.cos(np.pi * x[0]) * decay_factor,
                                          np.sin(np.pi * x[0]) * np.cos(np.pi * x[1]) * decay_factor)))


w = fem.Function(velocity_function_space, name="w") 
w.x.array[:] = 2 * u_n.x.array - u_n_1.x.array

# %%
from ufl import FacetNormal, dx, ds, dS, dot, outer, div, jump, avg, grad, conditional, ge, inner, transpose
from dolfinx.fem.petsc import create_matrix, create_vector

# coefficients for second order backward difference for time
# first time step uses first order backward differences 
diff_coef_1 = fem.Constant(domain, 1.0)
diff_coef_2 = fem.Constant(domain, -1.0)
diff_coef_3 = fem.Constant(domain, 0.0)

n = FacetNormal(domain)
u_upwind = conditional(ge(dot(w('+'), n('+')), 0), u('+'), u('-')) # uses previous solution to get upwind direction 

# define forms and allocate matrices
m_form = (rho/TIME_STEP) * diff_coef_1 * dot(u, v) * dx
m_compiled = fem.form(m_form)
M = create_matrix(m_compiled)

# w('+') no estaba en el paper, lo inclui porque si no daba error
# PUEDE QUE OUTER SEA AL REVÉS
r_form = - dot(u, div(rho * outer(v, w))) * dx \
         + dot(w, n * dot(u, rho*v)) * ds \
         + dot(w('+'), n('+') * dot(u_upwind, jump(rho*v))) * dS \
         + mu * inner(grad(u) + transpose(grad(u)), grad(v)) * dx \
         + k_mu * dot(jump(u), jump(v)) * dS \
         - dot(dot(mu*(grad(u) + transpose(grad(u))), n), v) * ds \
         - dot(dot(avg(mu*(grad(u) + transpose(grad(u)))), n('+')), jump(v)) * dS \
         - dot(dot(mu*(grad(v) + transpose(grad(v))), n), u) * ds \
         - dot(dot(avg(mu*(grad(v) + transpose(grad(v)))), n('+')), jump(u)) * dS \
r_compiled = fem.form(r_form)
R = create_matrix(r_compiled)

b_form = - p * div(v) * dx \
         + avg(p) * dot(n('+'), jump(v)) * dS \
         + p * dot(n, v) * ds
b_compiled = fem.form(b_form)
B = create_matrix(b_compiled)

c_form = - dot(u, grad(q)) * dx \
         + dot(avg(u), n('+')) * jump(q) * dS \
         + dot(u, n) * q * ds 
c_compiled = fem.form(c_form)
C = create_matrix(c_compiled)

d_form = (rho/TIME_STEP) * dot(diff_coef_2*u_n + diff_coef_3*u_n_1, v) * dx
d_compiled = fem.form(d_form)
d = create_vector(d_compiled)

e_form = fem.Constant(domain, ScalarType(0.))*q*dx
e_compiled = fem.form(e_form)
e = create_vector(e_compiled)
# Out:
#   Cell In[5], line 27
#     - dot(dot(mu*(grad(v) + transpose(grad(v))), n), u) * ds \
#     ^
# IndentationError: unexpected indent

# %%
# assemble the forms into matrices/vectors
from dolfinx.fem.petsc import assemble_matrix, assemble_vector
from time import perf_counter

M.zeroEntries()
start_M = perf_counter()
assemble_matrix(M, m_compiled)
M.assemble()
end_M = perf_counter()

R.zeroEntries()
start_R = perf_counter()
assemble_matrix(R, r_compiled)
R.assemble()
end_R = perf_counter()

B.zeroEntries()
start_B = perf_counter()
assemble_matrix(B, b_compiled)
B.assemble()
end_B = perf_counter()

C.zeroEntries()
start_C = perf_counter()
assemble_matrix(C, c_compiled)
C.assemble()
end_C = perf_counter()

d.zeroEntries()
start_d = perf_counter()
assemble_vector(d, d_compiled)
d.assemble()
end_d = perf_counter()

e.zeroEntries()
start_e = perf_counter()
assemble_vector(e, e_compiled)
e.assemble()
end_e = perf_counter()

# %%
from petsc4py import PETSc

# intitialize solver for aproximate velocity
solver_velocity = PETSc.KSP().create(domain.comm)
solver_velocity.setType(PETSc.KSP.Type.GMRES)
pc_velocity = solver_velocity.getPC()
pc_velocity.setType(PETSc.PC.Type.ASM) 
pc_velocity.setASMType(PETSc.PC.ASMType.BASIC)  
solver_velocity.setTolerances(rtol=1e-15, atol=1e-15, max_it=100)

# initialize solver for M inverse
solver_M = PETSc.KSP().create()
solver_M.setType('preonly')
pc_M = solver_M.getPC()
pc_M.setType('lu')

# define PETSc matrix for P = C * M⁻¹ * B.
class PMat:
    def __init__(self, B, C, solver_M):
        self.B = B
        self.C = C
        self.solver_M = solver_M

    def mult(self, mat, p_in, p_out):
        # p_out = C*inv(M)*(B dot p_in)
        rows_b = B.getSize()[0] 
        tmp = PETSc.Vec().create(comm=PETSc.COMM_WORLD)
        tmp.setSizes(rows_b)
        tmp.setUp()
        self.B.mult(p_in, tmp) # tmp = B * p_in
        y = tmp.duplicate()
        self.solver_M.solve(tmp, y) # y = inv(M) *(B*p_in)
        self.C.mult(y, p_out) # p_out = C * y
        tmp.destroy()

#initialize P
size_rows, _ = C.getSizes()
_, size_cols = B.getSizes()
P = PETSc.Mat().createPython([size_rows, size_cols], context=PMat(B, C, solver_M))
P.setUp()

# initialize solver for pressure correction 
solver_pressure = PETSc.KSP().create()
solver_pressure.setType(PETSc.KSP.Type.GMRES)
pc_pressure = solver_pressure.getPC()
pc_pressure.setType(PETSc.PC.Type.HYPRE)
pc_pressure.setHYPREType("boomeramg")  
solver_pressure.setTolerances(rtol=1e-15, atol=1e-15, max_it=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 37
#      34         tmp.destroy()
#      36 #initialize P
# ---> 37 size_rows, _ = C.getSizes()
#      38 _, size_cols = B.getSizes()
#      39 P = PETSc.Mat().createPython([size_rows, size_cols], context=PMat(B, C, solver_M))
#
# NameError: name 'C' is not defined

# %%
from dolfinx.fem.petsc import assemble_matrix, assemble_vector

p_write = fem.Function(pressure_function_space)

time = TIME_STEP # not 0, initial conditions are given
p_guess = PETSc.Vec().createMPI(B.getSizes()[1])
p_guess.set(0.0)  # initial guess for initial time: zero pressure

u_file = io.VTXWriter(domain.comm, "u.bp", u_n)
p_file = io.VTXWriter(domain.comm, "p.bp", p_write)
u_file.write(time)
p_file.write(time)

while time < FINAL_TIME:
    if DEBUG:
        i = 0
        start_iter = perf_counter()
    
    # iterative pressure correction
    while True:  
        # step 1: aproximate velocity u_star
        # RHS = d - B dot p_guess
        rhs_velocity = d.copy() 
        temp = d.duplicate() # size of u
        B.mult(p_guess, temp)
        rhs_velocity.axpy(-1.0, temp)
        
        # LHS = A = M + R
        A = M.copy()
        A.axpy(1.0, R, structure=PETSc.Mat.Structure.DIFFERENT_NONZERO_PATTERN)

        # solve for u_star
        u_star = d.duplicate()  # create vector with same size as d
        solver_velocity.setOperators(A) # !! SET OPERATOR NO VA ACA
        solver_velocity.solve(rhs_velocity, u_star)
        
        # step 2: pressure correction
        # compute y = inv(M) * (B dot p_guess) by solving M dot y = B dot p_guess
        rhs_y = temp.duplicate() # same size as u, since B maps from p to u   
        B.mult(p_guess, rhs_y)
        y = rhs_y.duplicate()
        solver_M.setOperators(M)
        solver_M.solve(rhs_y, y) 

        #   RHS = C*inv(M)*B dot p_guess - e + C dot u_star = C dot y - e + C dot u_star.
        rhs_pressure = e.copy() # size of p
        rhs_pressure.scale(-1.0) 
        temp = e.duplicate() # size of p
        C.mult(u_star, temp)
        rhs_pressure.axpy(1.0, temp) 
        C.mult(y, temp)  
        rhs_pressure.axpy(1.0, temp)

        # LHS = C*inv(M)*B = P
        # !!! LOS SET OPERATORS VAN UN CICLO MAS AFUERA, YA QUE ACA ADENTRO NO CAMBIAN
        solver_pressure.setOperators(P) 

        # solve for p_new
        p_new = p_guess.duplicate() 
        solver_pressure.solve(rhs_pressure, p_new)
        
        # step 3: velocity correction
        # compute u = - inv(M) * B dot (p_new-p_guess) by solving M dot u = - B dot (p_new-p_guess) 
        dp = p_new.copy()
        dp.axpy(-1.0, p_guess)  
        temp = d.duplicate() # size of u
        B.mult(dp, temp)  
        u_new = u_star.duplicate()
        solver_M.solve(temp, u_new)

        # update p_guess for next iteration 
        p_new.copy(result=p_guess)
    
        # check convergence
        u_residue = u_star.copy()
        u_residue.axpy(-1.0, u_new)
        if u_residue.norm() <= PRESSURE_CORRECTION_TOLERANCE:
            if DEBUG:
                print(f"Time step: {time/TIME_STEP}, finished pressure correction iterations.")
            break

        if DEBUG:
            i += 1
            if i%1==0:
                print(f"Time step: {time/TIME_STEP}, pressure iteration {i}, residue: {u_residue.norm()}.")
                temp = start_iter
                start_iter = perf_counter()
                print(f"Average pressure iteration runtime (seconds): {(start_iter - temp)/10}")

    
    # re-assign u_n, u_n_1 and w considering new solution
    u_n_1.x.array[:] = u_n.x.array
    u_n.x.array[:] = u_new.getArray()
    w.x.array[:] = 2 * u_n.x.array - u_n_1.x.array

    # save solution to xdmf file
    p_write.x.array[:] = p_new.getArray()
    u_file.write(time)
    p_file.write(time)
    
    # re-assemble time dependent forms
    R.zeroEntries()
    assemble_matrix(R, r_compiled)
    R.assemble()

    d.zeroEntries()
    assemble_vector(d, d_compiled)
    d.assemble()
    
    e.zeroEntries()
    assemble_vector(e, e_compiled)
    e.assemble()
    
    time += TIME_STEP
    if time > TIME_STEP:
        diff_coef_1.value = 3/2
        diff_coef_2.value = -2.0
        diff_coef_3.value = 1/2

        # re-assemble M since diff_coef_1 has changed
        M.zeroEntries()
        assemble_matrix(M, m_compiled)
        M.assemble()

u_file.close()
p_file.close()
# Out:
# Time step: 1.0, pressure iteration 1, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.04628479680000055
# Time step: 1.0, pressure iteration 2, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.5855533796999908
# Time step: 1.0, pressure iteration 3, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.7855738966999979
# Time step: 1.0, pressure iteration 4, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.39368703350000944
# Time step: 1.0, pressure iteration 5, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.06941777409999758
# Time step: 1.0, pressure iteration 6, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.08931219240000701
# Time step: 1.0, pressure iteration 7, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.6551290010999992
# Time step: 1.0, pressure iteration 8, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.47831848069999977
# Time step: 1.0, pressure iteration 9, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.10384092719998535
# Time step: 1.0, pressure iteration 10, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.06326455600001282
# Time step: 1.0, pressure iteration 11, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 1.054921176899984
# Time step: 1.0, pressure iteration 12, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.05745992010001828
# Time step: 1.0, pressure iteration 13, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.3646555869999929
# Time step: 1.0, pressure iteration 14, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 32.900852214999986
# Time step: 1.0, pressure iteration 15, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008797008999999889
# Time step: 1.0, pressure iteration 16, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008741473700001733
# Time step: 1.0, pressure iteration 17, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00859479430000647
# Time step: 1.0, pressure iteration 18, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0051339075000214505
# Time step: 1.0, pressure iteration 19, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008664885500002129
# Time step: 1.0, pressure iteration 20, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009512833400003728
# Time step: 1.0, pressure iteration 21, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008624364399975094
# Time step: 1.0, pressure iteration 22, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008317284399981872
# Time step: 1.0, pressure iteration 23, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008785552900008042
# Time step: 1.0, pressure iteration 24, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0047876083000119255
# Time step: 1.0, pressure iteration 25, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008584378300020035
# Time step: 1.0, pressure iteration 26, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008369304500001817
# Time step: 1.0, pressure iteration 27, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009522096399996372
# Time step: 1.0, pressure iteration 28, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009698276099970825
# Time step: 1.0, pressure iteration 29, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009631702800015773
# Time step: 1.0, pressure iteration 30, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005820206799990046
# Time step: 1.0, pressure iteration 31, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008293042300010711
# Time step: 1.0, pressure iteration 32, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008567773200002193
# Time step: 1.0, pressure iteration 33, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008349953400011146
# Time step: 1.0, pressure iteration 34, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007935904099986147
# Time step: 1.0, pressure iteration 35, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00813125569998192
# Time step: 1.0, pressure iteration 36, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0048513605000152895
# Time step: 1.0, pressure iteration 37, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008090152500017211
# Time step: 1.0, pressure iteration 38, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00801184439997087
# Time step: 1.0, pressure iteration 39, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008022971300033533
# Time step: 1.0, pressure iteration 40, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008306149299960453
# Time step: 1.0, pressure iteration 41, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008685815600028946
# Time step: 1.0, pressure iteration 42, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0055798379999941975
# Time step: 1.0, pressure iteration 43, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00825325209998482
# Time step: 1.0, pressure iteration 44, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008148101799997675
# Time step: 1.0, pressure iteration 45, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007947214100022392
# Time step: 1.0, pressure iteration 46, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008279374199992163
# Time step: 1.0, pressure iteration 47, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008814819000008356
# Time step: 1.0, pressure iteration 48, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005039643200007049
# Time step: 1.0, pressure iteration 49, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009312979699961943
# Time step: 1.0, pressure iteration 50, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008901545300022917
# Time step: 1.0, pressure iteration 51, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009116418099984003
# Time step: 1.0, pressure iteration 52, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009105838999994375
# Time step: 1.0, pressure iteration 53, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008363852499996938
# Time step: 1.0, pressure iteration 54, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004873446600004172
# Time step: 1.0, pressure iteration 55, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008278936200031239
# Time step: 1.0, pressure iteration 56, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00834662849997585
# Time step: 1.0, pressure iteration 57, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007741746400006378
# Time step: 1.0, pressure iteration 58, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008676762499999314
# Time step: 1.0, pressure iteration 59, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00829096729999037
# Time step: 1.0, pressure iteration 60, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004846129499992457
# Time step: 1.0, pressure iteration 61, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007922569000038493
# Time step: 1.0, pressure iteration 62, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008031668299963712
# Time step: 1.0, pressure iteration 63, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008339774400019451
# Time step: 1.0, pressure iteration 64, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009876101700001527
# Time step: 1.0, pressure iteration 65, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009671614999979284
# Time step: 1.0, pressure iteration 66, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0057672676000038335
# Time step: 1.0, pressure iteration 67, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00923995550001564
# Time step: 1.0, pressure iteration 68, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00934428079999634
# Time step: 1.0, pressure iteration 69, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009128264099990702
# Time step: 1.0, pressure iteration 70, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008174652900015645
# Time step: 1.0, pressure iteration 71, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008986685599984412
# Time step: 1.0, pressure iteration 72, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005383472299990899
# Time step: 1.0, pressure iteration 73, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009006568700033312
# Time step: 1.0, pressure iteration 74, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008507456999996065
# Time step: 1.0, pressure iteration 75, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00836162850000619
# Time step: 1.0, pressure iteration 76, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008320598399996016
# Time step: 1.0, pressure iteration 77, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00891839539999637
# Time step: 1.0, pressure iteration 78, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005032311100012521
# Time step: 1.0, pressure iteration 79, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007913807999966594
# Time step: 1.0, pressure iteration 80, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008459601799995654
# Time step: 1.0, pressure iteration 81, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009315978700033156
# Time step: 1.0, pressure iteration 82, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00790298699998857
# Time step: 1.0, pressure iteration 83, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008490914899994095
# Time step: 1.0, pressure iteration 84, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005099736400006804
# Time step: 1.0, pressure iteration 85, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009204266300002928
# Time step: 1.0, pressure iteration 86, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009411611099994843
# Time step: 1.0, pressure iteration 87, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009484613299991906
# Time step: 1.0, pressure iteration 88, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008859346200006257
# Time step: 1.0, pressure iteration 89, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008657922500015047
# Time step: 1.0, pressure iteration 90, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005428190499969787
# Time step: 1.0, pressure iteration 91, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.010269811000034679
# Time step: 1.0, pressure iteration 92, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009590218699986507
# Time step: 1.0, pressure iteration 93, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009607027699985338
# Time step: 1.0, pressure iteration 94, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009829994500023531
# Time step: 1.0, pressure iteration 95, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009670387899996058
# Time step: 1.0, pressure iteration 96, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0054912807999699
# Time step: 1.0, pressure iteration 97, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00803609630002029
# Time step: 1.0, pressure iteration 98, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00926363459998356
# Time step: 1.0, pressure iteration 99, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009772818300007202
# Time step: 1.0, pressure iteration 100, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.011459296000020913
# Time step: 1.0, pressure iteration 101, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.010472650699966835
# Time step: 1.0, pressure iteration 102, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.006291596500022934
# Time step: 1.0, pressure iteration 103, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.010938048199977856
# Time step: 1.0, pressure iteration 104, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009699722100003782
# Time step: 1.0, pressure iteration 105, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008976699599998028
# Time step: 1.0, pressure iteration 106, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008525282000027801
# Time step: 1.0, pressure iteration 107, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009264171599988913
# Time step: 1.0, pressure iteration 108, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005599964100019861
# Time step: 1.0, pressure iteration 109, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009159237199992277
# Time step: 1.0, pressure iteration 110, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009618299699968701
# Time step: 1.0, pressure iteration 111, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.011232673300037277
# Time step: 1.0, pressure iteration 112, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008446182799980306
# Time step: 1.0, pressure iteration 113, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00835455040000852
# Time step: 1.0, pressure iteration 114, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005170431699980327
# Time step: 1.0, pressure iteration 115, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008167723800033855
# Time step: 1.0, pressure iteration 116, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007954989099971499
# Time step: 1.0, pressure iteration 117, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008445818800009875
# Time step: 1.0, pressure iteration 118, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008134762700001375
# Time step: 1.0, pressure iteration 119, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.011345931699997891
# Time step: 1.0, pressure iteration 120, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0061880820000169475
# Time step: 1.0, pressure iteration 121, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008665774599967336
# Time step: 1.0, pressure iteration 122, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008294933200022569
# Time step: 1.0, pressure iteration 123, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00829774029998589
# Time step: 1.0, pressure iteration 124, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00804654240000673
# Time step: 1.0, pressure iteration 125, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009022670800004563
# Time step: 1.0, pressure iteration 126, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0054027774000132926
# Time step: 1.0, pressure iteration 127, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009610063699983584
# Time step: 1.0, pressure iteration 128, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00900996169998507
# Time step: 1.0, pressure iteration 129, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009752557199999502
# Time step: 1.0, pressure iteration 130, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.011345619700023235
# Time step: 1.0, pressure iteration 131, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.010782496699994227
# Time step: 1.0, pressure iteration 132, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0062928525000188525
# Time step: 1.0, pressure iteration 133, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.010248378899996169
# Time step: 1.0, pressure iteration 134, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009690232999992077
# Time step: 1.0, pressure iteration 135, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009735144199976276
# Time step: 1.0, pressure iteration 136, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.010189883700013525
# Time step: 1.0, pressure iteration 137, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009685639000008451
# Time step: 1.0, pressure iteration 138, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0059189671999774875
# Time step: 1.0, pressure iteration 139, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009935050800004319
# Time step: 1.0, pressure iteration 140, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00836768449998999
# Time step: 1.0, pressure iteration 141, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008767010900010063
# Time step: 1.0, pressure iteration 142, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008113548700021057
# Time step: 1.0, pressure iteration 143, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00810704259997692
# Time step: 1.0, pressure iteration 144, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004801976299995658
# Time step: 1.0, pressure iteration 145, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007872875900011423
# Time step: 1.0, pressure iteration 146, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00813499870000669
# Time step: 1.0, pressure iteration 147, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007985771199992086
# Time step: 1.0, pressure iteration 148, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008440414699998655
# Time step: 1.0, pressure iteration 149, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008057929500000682
# Time step: 1.0, pressure iteration 150, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.00564778920002027
# Time step: 1.0, pressure iteration 151, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.011473298099963359
# Time step: 1.0, pressure iteration 152, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009862400600013643
# Time step: 1.0, pressure iteration 153, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009905713800026205
# Time step: 1.0, pressure iteration 154, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008654442499982906
# Time step: 1.0, pressure iteration 155, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008642722400009007
# Time step: 1.0, pressure iteration 156, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005165472599992426
# Time step: 1.0, pressure iteration 157, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008613959400008753
# Time step: 1.0, pressure iteration 158, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008417814699987503
# Time step: 1.0, pressure iteration 159, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008495859899994684
# Time step: 1.0, pressure iteration 160, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008410916699995141
# Time step: 1.0, pressure iteration 161, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008440832700034661
# Time step: 1.0, pressure iteration 162, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0053486592999888675
# Time step: 1.0, pressure iteration 163, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008941548399980093
# Time step: 1.0, pressure iteration 164, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008634327400022812
# Time step: 1.0, pressure iteration 165, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009857785599979251
# Time step: 1.0, pressure iteration 166, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008687204600028054
# Time step: 1.0, pressure iteration 167, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008362387499983016
# Time step: 1.0, pressure iteration 168, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004744027200013079
# Time step: 1.0, pressure iteration 169, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008710553699984303
# Time step: 1.0, pressure iteration 170, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008697084599998562
# Time step: 1.0, pressure iteration 171, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008474176900017482
# Time step: 1.0, pressure iteration 172, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008948605499972473
# Time step: 1.0, pressure iteration 173, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00831976429999486
# Time step: 1.0, pressure iteration 174, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004840721500022483
# Time step: 1.0, pressure iteration 175, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008064713499970821
# Time step: 1.0, pressure iteration 176, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008046686400030012
# Time step: 1.0, pressure iteration 177, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007831857700011824
# Time step: 1.0, pressure iteration 178, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008559252099985315
# Time step: 1.0, pressure iteration 179, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009469589299988002
# Time step: 1.0, pressure iteration 180, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.00547394670002177
# Time step: 1.0, pressure iteration 181, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007810157599988088
# Time step: 1.0, pressure iteration 182, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007782832500015502
# Time step: 1.0, pressure iteration 183, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008049547399969015
# Time step: 1.0, pressure iteration 184, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008142458800011809
# Time step: 1.0, pressure iteration 185, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008270658099991123
# Time step: 1.0, pressure iteration 186, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0052591610000035875
# Time step: 1.0, pressure iteration 187, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008856673099990076
# Time step: 1.0, pressure iteration 188, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00964148190000742
# Time step: 1.0, pressure iteration 189, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008583048199989207
# Time step: 1.0, pressure iteration 190, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.010100440400037769
# Time step: 1.0, pressure iteration 191, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009957301999975243
# Time step: 1.0, pressure iteration 192, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005855619900012243
# Time step: 1.0, pressure iteration 193, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009980689999974857
# Time step: 1.0, pressure iteration 194, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.0098743227000341
# Time step: 1.0, pressure iteration 195, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009279175599976952
# Time step: 1.0, pressure iteration 196, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00954145549999339
# Time step: 1.0, pressure iteration 197, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009082826900021245
# Time step: 1.0, pressure iteration 198, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.00486616260000119
# Time step: 1.0, pressure iteration 199, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00836094950000188
# Time step: 1.0, pressure iteration 200, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008460124800012635
# Time step: 1.0, pressure iteration 201, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007667439199985892
# Time step: 1.0, pressure iteration 202, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.0076903241999843885
# Time step: 1.0, pressure iteration 203, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008443910699998013
# Time step: 1.0, pressure iteration 204, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005379352399995696
# Time step: 1.0, pressure iteration 205, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009431069099991873
# Time step: 1.0, pressure iteration 206, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009243755500028783
# Time step: 1.0, pressure iteration 207, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00954078549998485
# Time step: 1.0, pressure iteration 208, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008576232199993683
# Time step: 1.0, pressure iteration 209, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009223553500032722
# Time step: 1.0, pressure iteration 210, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005318932099999074
# Time step: 1.0, pressure iteration 211, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009087834999991173
# Time step: 1.0, pressure iteration 212, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009245412500013117
# Time step: 1.0, pressure iteration 213, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009557357499988938
# Time step: 1.0, pressure iteration 214, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.010086792399988553
# Time step: 1.0, pressure iteration 215, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.009386967999989792
# Time step: 1.0, pressure iteration 216, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0055456469000091605
# Time step: 1.0, pressure iteration 217, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008891972299988993
# Time step: 1.0, pressure iteration 218, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008611080300033791
# Time step: 1.0, pressure iteration 219, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008720065699981206
# Time step: 1.0, pressure iteration 220, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007836654699985957
# Time step: 1.0, pressure iteration 221, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007785983500025395
# Time step: 1.0, pressure iteration 222, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005229525899994769
# Time step: 1.0, pressure iteration 223, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008023937300004036
# Time step: 1.0, pressure iteration 224, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.0075468776999969124
# Time step: 1.0, pressure iteration 225, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007798274600008881
# Time step: 1.0, pressure iteration 226, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007659247099991262
# Time step: 1.0, pressure iteration 227, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00818451489999461
# Time step: 1.0, pressure iteration 228, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004946974799986492
# Time step: 1.0, pressure iteration 229, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007868588800010911
# Time step: 1.0, pressure iteration 230, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00856193119998352
# Time step: 1.0, pressure iteration 231, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007811056600030497
# Time step: 1.0, pressure iteration 232, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008394566599963581
# Time step: 1.0, pressure iteration 233, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008054866500015124
# Time step: 1.0, pressure iteration 234, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004947230800007673
# Time step: 1.0, pressure iteration 235, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007911259000002247
# Time step: 1.0, pressure iteration 236, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007835689700004877
# Time step: 1.0, pressure iteration 237, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007985107200011044
# Time step: 1.0, pressure iteration 238, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009219261399994138
# Time step: 1.0, pressure iteration 239, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008874420199981614
# Time step: 1.0, pressure iteration 240, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005368184300004941
# Time step: 1.0, pressure iteration 241, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00807029650000004
# Time step: 1.0, pressure iteration 242, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007972425199977807
# Time step: 1.0, pressure iteration 243, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008036570400008713
# Time step: 1.0, pressure iteration 244, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.0078852198000277
# Time step: 1.0, pressure iteration 245, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008037884399982431
# Time step: 1.0, pressure iteration 246, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005043105200002174
# Time step: 1.0, pressure iteration 247, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007969899199997599
# Time step: 1.0, pressure iteration 248, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00820691590001843
# Time step: 1.0, pressure iteration 249, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008121526700006144
# Time step: 1.0, pressure iteration 250, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00820959299999231
# Time step: 1.0, pressure iteration 251, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008113165599979766
# Time step: 1.0, pressure iteration 252, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004735910199997306
# Time step: 1.0, pressure iteration 253, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007830858600027569
# Time step: 1.0, pressure iteration 254, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008105201599983047
# Time step: 1.0, pressure iteration 255, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007853797799998573
# Time step: 1.0, pressure iteration 256, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007979605199989238
# Time step: 1.0, pressure iteration 257, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00794052199998987
# Time step: 1.0, pressure iteration 258, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004783046300008209
# Time step: 1.0, pressure iteration 259, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007653869100022348
# Time step: 1.0, pressure iteration 260, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007846855799971308
# Time step: 1.0, pressure iteration 261, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00790144290003809
# Time step: 1.0, pressure iteration 262, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007984019199966497
# Time step: 1.0, pressure iteration 263, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007768224400024337
# Time step: 1.0, pressure iteration 264, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004926338799987206
# Time step: 1.0, pressure iteration 265, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007987994299992352
# Time step: 1.0, pressure iteration 266, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007529717600027653
# Time step: 1.0, pressure iteration 267, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008216283000001568
# Time step: 1.0, pressure iteration 268, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007892618899995795
# Time step: 1.0, pressure iteration 269, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008077972499995667
# Time step: 1.0, pressure iteration 270, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0046984709999833285
# Time step: 1.0, pressure iteration 271, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007716450299994904
# Time step: 1.0, pressure iteration 272, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008060187499995663
# Time step: 1.0, pressure iteration 273, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007923461000018506
# Time step: 1.0, pressure iteration 274, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00752504960000806
# Time step: 1.0, pressure iteration 275, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007897260899972025
# Time step: 1.0, pressure iteration 276, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004695136999998795
# Time step: 1.0, pressure iteration 277, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00768962720003401
# Time step: 1.0, pressure iteration 278, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00847165289997065
# Time step: 1.0, pressure iteration 279, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007938971000021411
# Time step: 1.0, pressure iteration 280, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.0079976213000009
# Time step: 1.0, pressure iteration 281, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008345648399972561
# Time step: 1.0, pressure iteration 282, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004764850300034595
# Time step: 1.0, pressure iteration 283, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00790617489997203
# Time step: 1.0, pressure iteration 284, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00788985090002825
# Time step: 1.0, pressure iteration 285, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00757842879997952
# Time step: 1.0, pressure iteration 286, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007723891300020114
# Time step: 1.0, pressure iteration 287, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007688160199995764
# Time step: 1.0, pressure iteration 288, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004874395599972559
# Time step: 1.0, pressure iteration 289, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00780122860001029
# Time step: 1.0, pressure iteration 290, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008162028800006738
# Time step: 1.0, pressure iteration 291, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007785625499991511
# Time step: 1.0, pressure iteration 292, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00802387940002518
# Time step: 1.0, pressure iteration 293, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00805119139999988
# Time step: 1.0, pressure iteration 294, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005536321899990071
# Time step: 1.0, pressure iteration 295, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007961850099991351
# Time step: 1.0, pressure iteration 296, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008082024499981345
# Time step: 1.0, pressure iteration 297, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.0076544746000308805
# Time step: 1.0, pressure iteration 298, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007803989700005331
# Time step: 1.0, pressure iteration 299, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007778885599964269
# Time step: 1.0, pressure iteration 300, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004721540600030494
# Time step: 1.0, pressure iteration 301, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008132815999988451
# Time step: 1.0, pressure iteration 302, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007715159400004268
# Time step: 1.0, pressure iteration 303, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007721439399983865
# Time step: 1.0, pressure iteration 304, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00793644420000419
# Time step: 1.0, pressure iteration 305, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008095211899990318
# Time step: 1.0, pressure iteration 306, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004673857400030101
# Time step: 1.0, pressure iteration 307, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007771666600001481
# Time step: 1.0, pressure iteration 308, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00796388730000217
# Time step: 1.0, pressure iteration 309, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007876162000002296
# Time step: 1.0, pressure iteration 310, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.00783119379998425
# Time step: 1.0, pressure iteration 311, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007925277200001801
# Time step: 1.0, pressure iteration 312, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004822431999991749
# Time step: 1.0, pressure iteration 313, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007800673700012339
# Time step: 1.0, pressure iteration 314, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008968440299986469
# Time step: 1.0, pressure iteration 315, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008281556600013572
# Time step: 1.0, pressure iteration 316, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007926226199970188
# Time step: 1.0, pressure iteration 317, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008720128300001306
# Time step: 1.0, pressure iteration 318, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004624870200041186
# Time step: 1.0, pressure iteration 319, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.0077555754999593775
# Time step: 1.0, pressure iteration 320, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007850251000036224
# Time step: 1.0, pressure iteration 321, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008452996200003327
# Time step: 1.0, pressure iteration 322, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.0077596795999852475
# Time step: 1.0, pressure iteration 323, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007653383099977873
# Time step: 1.0, pressure iteration 324, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004713180500039016
# Time step: 1.0, pressure iteration 325, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009845703799965123
# Time step: 1.0, pressure iteration 326, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007836971799997627
# Time step: 1.0, pressure iteration 327, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008056405800016365
# Time step: 1.0, pressure iteration 328, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008157928099990386
# Time step: 1.0, pressure iteration 329, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.0081907622000017
# Time step: 1.0, pressure iteration 330, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004687718400009544
# Time step: 1.0, pressure iteration 331, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008090828900003543
# Time step: 1.0, pressure iteration 332, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00791948319997573
# Time step: 1.0, pressure iteration 333, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007868347900011941
# Time step: 1.0, pressure iteration 334, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007846497900027316
# Time step: 1.0, pressure iteration 335, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007944780299976629
# Time step: 1.0, pressure iteration 336, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005362321099983092
# Time step: 1.0, pressure iteration 337, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007847545900040132
# Time step: 1.0, pressure iteration 338, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007715551299997969
# Time step: 1.0, pressure iteration 339, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008066978799979552
# Time step: 1.0, pressure iteration 340, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007836253799996484
# Time step: 1.0, pressure iteration 341, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00808505889999651
# Time step: 1.0, pressure iteration 342, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004749923700001091
# Time step: 1.0, pressure iteration 343, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007803059700017911
# Time step: 1.0, pressure iteration 344, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007933873199999653
# Time step: 1.0, pressure iteration 345, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008175151199975517
# Time step: 1.0, pressure iteration 346, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007633318000034706
# Time step: 1.0, pressure iteration 347, residue: 5.2431227500700174e+70.
# ...
# Average pressure iteration runtime (seconds): 0.007493592599985277
# Time step: 1.0, pressure iteration 15489, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007444694400010121
# Time step: 1.0, pressure iteration 15490, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007884622300025512
# Time step: 1.0, pressure iteration 15491, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007400120099964625
# Time step: 1.0, pressure iteration 15492, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0043854000999999695
# Time step: 1.0, pressure iteration 15493, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007522292700014077
# Time step: 1.0, pressure iteration 15494, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007753011700015122
# Time step: 1.0, pressure iteration 15495, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007469264500014105
# Time step: 1.0, pressure iteration 15496, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.0075258126999870004
# Time step: 1.0, pressure iteration 15497, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008971965999990061
# Time step: 1.0, pressure iteration 15498, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005074486100011199
# Time step: 1.0, pressure iteration 15499, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008309587099984129
# Time step: 1.0, pressure iteration 15500, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007993652699997255
# Time step: 1.0, pressure iteration 15501, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00760246710001411
# Time step: 1.0, pressure iteration 15502, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007618212099987432
# Time step: 1.0, pressure iteration 15503, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008702948800009835
# Time step: 1.0, pressure iteration 15504, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005110823299992262
# Time step: 1.0, pressure iteration 15505, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008133682300012879
# Time step: 1.0, pressure iteration 15506, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008485102899976482
# Time step: 1.0, pressure iteration 15507, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008143427400000292
# Time step: 1.0, pressure iteration 15508, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007563956900003177
# Time step: 1.0, pressure iteration 15509, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007858309199991708
# Time step: 1.0, pressure iteration 15510, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0048055219000161745
# Time step: 1.0, pressure iteration 15511, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007938275500009695
# Time step: 1.0, pressure iteration 15512, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008025999899973612
# Time step: 1.0, pressure iteration 15513, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008931649800024389
# Time step: 1.0, pressure iteration 15514, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008019684900000356
# Time step: 1.0, pressure iteration 15515, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00930937839998478
# Time step: 1.0, pressure iteration 15516, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005197470600023735
# Time step: 1.0, pressure iteration 15517, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.009145854799999142
# Time step: 1.0, pressure iteration 15518, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.010049356699983036
# Time step: 1.0, pressure iteration 15519, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008656017600014821
# Time step: 1.0, pressure iteration 15520, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008652180599983694
# Time step: 1.0, pressure iteration 15521, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008397069500006182
# Time step: 1.0, pressure iteration 15522, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004641457200023069
# Time step: 1.0, pressure iteration 15523, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007609915099965292
# Time step: 1.0, pressure iteration 15524, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007726484600016193
# Time step: 1.0, pressure iteration 15525, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007755772700011221
# Time step: 1.0, pressure iteration 15526, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008382346400003371
# Time step: 1.0, pressure iteration 15527, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007868097299979126
# Time step: 1.0, pressure iteration 15528, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005200128600017706
# Time step: 1.0, pressure iteration 15529, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007594167999968704
# Time step: 1.0, pressure iteration 15530, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008543169099993975
# Time step: 1.0, pressure iteration 15531, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008425484700001106
# Time step: 1.0, pressure iteration 15532, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009310918400024093
# Time step: 1.0, pressure iteration 15533, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008560031199976947
# Time step: 1.0, pressure iteration 15534, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0047473647000060735
# Time step: 1.0, pressure iteration 15535, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008412071500015373
# Time step: 1.0, pressure iteration 15536, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009156954899981428
# Time step: 1.0, pressure iteration 15537, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.008806092200029526
# Time step: 1.0, pressure iteration 15538, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007447848399988288
# Time step: 1.0, pressure iteration 15539, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007912283399991792
# Time step: 1.0, pressure iteration 15540, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.0051383324000198625
# Time step: 1.0, pressure iteration 15541, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.00896489990000191
# Time step: 1.0, pressure iteration 15542, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.009343582699966647
# Time step: 1.0, pressure iteration 15543, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00952743040002133
# Time step: 1.0, pressure iteration 15544, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009145946699982232
# Time step: 1.0, pressure iteration 15545, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.00814135340001485
# Time step: 1.0, pressure iteration 15546, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004975078699999358
# Time step: 1.0, pressure iteration 15547, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008227425699988088
# Time step: 1.0, pressure iteration 15548, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008351643300011346
# Time step: 1.0, pressure iteration 15549, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.009250784300002124
# Time step: 1.0, pressure iteration 15550, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009201195000014196
# Time step: 1.0, pressure iteration 15551, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007413693199987392
# Time step: 1.0, pressure iteration 15552, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004681407299995044
# Time step: 1.0, pressure iteration 15553, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.008476282899982835
# Time step: 1.0, pressure iteration 15554, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.008823382400032642
# Time step: 1.0, pressure iteration 15555, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.0090346371999658
# Time step: 1.0, pressure iteration 15556, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008055931100034285
# Time step: 1.0, pressure iteration 15557, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.008743782999999894
# Time step: 1.0, pressure iteration 15558, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004814816899988727
# Time step: 1.0, pressure iteration 15559, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007461100399996212
# Time step: 1.0, pressure iteration 15560, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007793339899990315
# Time step: 1.0, pressure iteration 15561, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.00883805440003016
# Time step: 1.0, pressure iteration 15562, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008445690799999284
# Time step: 1.0, pressure iteration 15563, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007910610399994767
# Time step: 1.0, pressure iteration 15564, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.005239924699981202
# Time step: 1.0, pressure iteration 15565, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007896793400004754
# Time step: 1.0, pressure iteration 15566, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.0075457668000126436
# Time step: 1.0, pressure iteration 15567, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007745987599992077
# Time step: 1.0, pressure iteration 15568, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.009068491500011077
# Time step: 1.0, pressure iteration 15569, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007691714399970806
# Time step: 1.0, pressure iteration 15570, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004414453200024582
# Time step: 1.0, pressure iteration 15571, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007550052799979312
# Time step: 1.0, pressure iteration 15572, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007957020599997122
# Time step: 1.0, pressure iteration 15573, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.0076215001000036866
# Time step: 1.0, pressure iteration 15574, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007392328200012344
# Time step: 1.0, pressure iteration 15575, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007687998399978824
# Time step: 1.0, pressure iteration 15576, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004577838900013375
# Time step: 1.0, pressure iteration 15577, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007451340399984474
# Time step: 1.0, pressure iteration 15578, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007431826300035027
# Time step: 1.0, pressure iteration 15579, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.0091876659999798
# Time step: 1.0, pressure iteration 15580, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008069139000008363
# Time step: 1.0, pressure iteration 15581, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007910402400011663
# Time step: 1.0, pressure iteration 15582, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004581982999980028
# Time step: 1.0, pressure iteration 15583, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007968506599991088
# Time step: 1.0, pressure iteration 15584, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.007658278300004895
# Time step: 1.0, pressure iteration 15585, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007489582500011238
# Time step: 1.0, pressure iteration 15586, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.008124817399993845
# Time step: 1.0, pressure iteration 15587, residue: 5.2431227500700174e+70.
# Average pressure iteration runtime (seconds): 0.007482184499986033
# Time step: 1.0, pressure iteration 15588, residue: 8.090217428204998e+71.
# Average pressure iteration runtime (seconds): 0.004477350500019383
# Time step: 1.0, pressure iteration 15589, residue: 1326628284692329.5.
# Average pressure iteration runtime (seconds): 0.007400266100012232
# Time step: 1.0, pressure iteration 15590, residue: 5.742605934910506e+28.
# Average pressure iteration runtime (seconds): 0.00774891769997339
# Time step: 1.0, pressure iteration 15591, residue: 3.7229258343221626e+42.
# Average pressure iteration runtime (seconds): 0.007606693100024131
# Time step: 1.0, pressure iteration 15592, residue: 2.7441833566032427e+56.
# Average pressure iteration runtime (seconds): 0.007467047499994805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 60
#      58 # solve for p_new
#      59 p_new = p_guess.duplicate()
# ---> 60 solver_pressure.solve(rhs_pressure, p_new)
#      62 # step 3: velocity correction
#      63 # compute u = - inv(M) * B dot (p_new-p_guess) by solving M dot u = - B dot (p_new-p_guess)
#      64 dp = p_new.copy()
#
# File petsc4py/PETSc/KSP.pyx:1782, in petsc4py.PETSc.KSP.solve()
#
# File petsc4py/PETSc/PETSc.pyx:323, in petsc4py.PETSc.PetscPythonErrorHandler()
#
# File petsc4py/PETSc/PETSc.pyx:323, in petsc4py.PETSc.PetscPythonErrorHandler()
#
#     [... skipping similar frames: petsc4py.PETSc.PetscPythonErrorHandler at line 323 (4 times)]
#
# File petsc4py/PETSc/PETSc.pyx:323, in petsc4py.PETSc.PetscPythonErrorHandler()
#
# File petsc4py/PETSc/libpetsc4py.pyx:755, in petsc4py.PETSc.MatMult_Python()
#
# Cell In[7], line 24, in PMat.mult(self, mat, p_in, p_out)
#      21     self.C = C
#      22     self.solver_M = solver_M
# ---> 24 def mult(self, mat, p_in, p_out):
#      25     # p_out = C*inv(M)*(B dot p_in)
#      26     rows_b = B.getSize()[0]
#      27     tmp = PETSc.Vec().create(comm=PETSc.COMM_WORLD)
#
# KeyboardInterrupt:
